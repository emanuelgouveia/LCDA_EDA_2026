# %%
import pandas as pd
df=pd.read_csv("tested.csv")
df

# %%
df.dtypes
#variaveis discretas nominais
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name               str
# Sex                str
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket             str
# Fare           float64
# Cabin              str
# Embarked           str
# dtype: object

# %%
cols_discretas=["Survived","Pclass","Sex","Parch","PassengerId","SibSp"]
for variavel in cols_discretas:
    print(df[variavel].value_counts())
# Out:
# Survived
# 0    266
# 1    152
# Name: count, dtype: int64
# Pclass
# 3    218
# 1    107
# 2     93
# Name: count, dtype: int64
# Sex
# male      266
# female    152
# Name: count, dtype: int64
# Parch
# 0    324
# 1     52
# 2     33
# 3      3
# 4      2
# 9      2
# 6      1
# 5      1
# Name: count, dtype: int64
# PassengerId
# 892     1
# 893     1
# 894     1
# 895     1
# 896     1
#        ..
# 1305    1
# 1306    1
# 1307    1
# 1308    1
# 1309    1
# Name: count, Length: 418, dtype: int64
# SibSp
# 0    283
# 1    110
# 2     14
# 3      4
# 4      4
# 8      2
# 5      1
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
colunas=["PassengerId","Survived","Pclass","Name","Sex","Age","SibSp","Parch","Ticket","Fare","Cabin","Embarked"]
for variavel in colunas:
    print(df.duplicated(variavel).sum())
# Out:
# 0
# 416
# 415
# 0
# 416
# 338
# 411
# 410
# 55
# 248
# 341
# 415

# %%
children_survived = df[(df["Age"] < 18) & (df["Survived"] == 1)]
print(children_survived)
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 104          996         1       3  Thomas, Mrs. Alexander (Thamine Thelma")"
# 117         1009         1       3            Sandstrom, Miss. Beatrice Irene
# 120         1012         1       2                       Watt, Miss. Bertha J
# 125         1017         1       3                   Cribb, Miss. Laura Alice
# 140         1032         1       3                Goodwin, Miss. Jessie Allis
# 175         1067         1       2                  Brown, Miss. Edith Eileen
# 203         1095         1       2                 Quick, Miss. Winifred Vera
# 250         1142         1       2                      West, Miss. Barbara J
# 263         1155         1       3               Klasen, Miss. Gertrud Emilia
# 283         1175         1       3                 Touma, Miss. Maria Youssef
# 284         1176         1       3                Rosblom, Miss. Salli Helena
# ...

# %%
df[["Age","Survived","Sex"]].groupby("Sex").mean()
# Out:
#               Age  Survived
# Sex
# female  30.272362       1.0
# male    30.272732       0.0

# %%
children_survived[["Age","Fare"]].mean()
# Out:
# Age      8.299412
# Fare    22.039459
# dtype: float64

# %%
children_survived = df[(df["Age"] < 18) & (df["Survived"] == 1)]
print(children_survived.nlargest(2,"Age"))
print(children_survived.nsmallest(2,"Age"))
# Out:
#      PassengerId  Survived  Pclass                      Name     Sex   Age  \
# 125         1017         1       3  Cribb, Miss. Laura Alice  female  17.0
# 315         1207         1       3      Hagardon, Miss. Kate  female  17.0
#
#      SibSp  Parch       Ticket     Fare Cabin Embarked
# 125      0      1       371362  16.1000   NaN        S
# 315      0      0  AQ/3. 30631   7.7333   NaN        Q
#      PassengerId  Survived  Pclass                                     Name  \
# 354         1246         1       3  Dean, Miss. Elizabeth Gladys Millvina""
# 250         1142         1       2                    West, Miss. Barbara J
#
#         Sex   Age  SibSp  Parch      Ticket    Fare Cabin Embarked
# 354  female  0.17      1      2   C.A. 2315  20.575   NaN        S
# 250  female  0.92      1      2  C.A. 34651  27.750   NaN        S
